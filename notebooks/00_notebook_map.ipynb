# %% [markdown]
# # Notebook map
#
# Read these notebooks in order. All notebooks use the same benchmark configuration API as the scripts.
#
# In each notebook, the first editable code cell contains the important controls:
#
# ```python
# dataset_name = "synthetic_time_space_fractional_RD"
# noise_percent = 0.5
# profile = "notebook"  # change to "paper" for paper-quality settings
# seed = 0
# ```
#
# If you use the same controls in a notebook and in `scripts/run_all_methods.py`, the results should be consistent because both paths call `benchmark_spec(...)` and the same method dispatcher.

# %% [markdown]
# | Notebook | Purpose |
# |---|---|
# | `05_end_to_end_weak_pareto_tutorial.ipynb` | Shortest end-to-end tutorial: builds the weak library, inspects a candidate, and runs Pareto selection. |
# | `01_step_by_step_candidate_libraries.ipynb` | Detailed comparison of vanilla and weak candidate libraries, the proposed method, and baselines. |
# | `02_run_paper_comparison.ipynb` | Runs the same benchmark command as the script and reads the output table interactively. |
# | `03_weak_grid_stridge_baseline.ipynb` | Explains the weak Grid-STRidge and fixed-library stability baselines. |
# | `04_split_weak_library_and_pareto_de.ipynb` | Separates weak-library construction from the Pareto-DE optimizer and inspects support-size progress. |

# %% [markdown]
# ## Final method framing
#
# The proposed method is:
#
# ```text
# weak_pareto = weak candidate library + best-subset Pareto-DE
# ```
#
# Baselines are:
#
# ```text
# vanilla_pareto       = vanilla/strong library + best-subset Pareto-DE
# weak_grid_stridge    = weak library + grid-search STRidge
# weak_fixed_stability = fixed weak grid library + stability-selected STRidge
# ```
